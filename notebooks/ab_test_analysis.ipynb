# %% [markdown]
# ## Problem & Context

# %% [markdown]
# ## Product Hypothesis

# %% [markdown]
# ## Metrics Definition

# %% [markdown]
# ## Experiment Design
#
# ### Target Uplift
# ### Minimum Detectable Effect (MDE)
# ### Risks & Assumptions

# %% [markdown]
# ## Decision Criteria

# %% [markdown]
# ## Next Steps
